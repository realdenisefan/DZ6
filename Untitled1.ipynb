# %% [markdown]
# Печатные газеты использовали свой формат дат для каждого выпуска. Для каждой
# газеты из списка напишите формат указанной даты для перевода в объект datetime:
#
# The Moscow Times - Wednesday, October 2, 2002
#
# The Guardian - Friday, 11.10.13
#
# Daily News - Thursday, 18 August 1977

# %%
from datetime import datetime

"Функция преобразует строку даты в объект datetime"
def parse_newspaper_date(newspaper, date_str, date_format):
    try:
        date_obj = datetime.strptime(date_str, date_format)
        return date_obj
    except ValueError as error:
        print(f"Ошибка при обработке {newspaper}: {error}")
        return None

newspapers = {
    "The Moscow Times": ("Wednesday, October 2, 2002", "%A, %B %d, %Y"),
    "The Guardian": ("Friday, 11.10.13", "%A, %d.%m.%y"),
    "Daily News": ("Thursday, 18 August 1977", "%A, %d %B %Y")
}

# Обработка газеты
for name, (date_str, form) in newspapers.items():
    result = parse_newspaper_date(name, date_str, form)
    if result:
        print(f"{name} - {result}")
# Out:
# The Moscow Times - 2002-10-02 00:00:00
# The Guardian - 2013-10-11 00:00:00
# Daily News - 1977-08-18 00:00:00
